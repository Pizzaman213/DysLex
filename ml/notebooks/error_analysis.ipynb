# %% [markdown]
# # Error Pattern Analysis
#
# This notebook explores dyslexia error patterns for model training.

# %%
# Import libraries
import json
import pandas as pd
from pathlib import Path

# %%
# Load error type definitions
with open('../error_classification/error_types.json') as f:
    error_types = json.load(f)

print(f"Loaded {len(error_types['categories'])} error categories")

# %%
# Load confusion pairs
with open('../confusion_pairs/en.json') as f:
    en_pairs = json.load(f)

print(f"Loaded {len(en_pairs['pairs'])} English confusion pairs")
